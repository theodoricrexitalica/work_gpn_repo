# %%
def showFolderTree(path,show_files=False,indentation=2,file_output=False):
    """
    Shows the content of a folder in a tree structure.
    path -(string)- path of the root folder we want to show.
    show_files -(boolean)-  Whether or not we want to see files listed.
                            Defaults to False.
    indentation -(int)- Indentation we want to use, defaults to 2.   
    file_output -(string)-  Path (including the name) of the file where we want
                            to save the tree.
    """

       
    tree = []

    if not show_files:
        for root, dirs, files in os.walk(path):
            level = root.replace(path, '').count(os.sep)
            indent = ' '*indentation*(level)
            tree.append('{}{}/'.format(indent,os.path.basename(root)))
            
    if show_files:
        for root, dirs, files in os.walk(path):
            level = root.replace(path, '').count(os.sep)
            indent = ' '*indentation*(level)
            tree.append('{}{}/'.format(indent,os.path.basename(root)))    
            for f in files:
                subindent=' ' * indentation * (level+1)
                tree.append('{}{}'.format(subindent,f))
            
    if file_output:
        output_file = open(file_output,'w')
        for line in tree:
            output_file.write(line)
            output_file.write('\n')
    else:
        # Default behaviour: print on screen.
        for line in tree:
            print(line)

# %%
Path.home()
# Out:
# WindowsPath('C:/Users/Dolgushin.TYu')

# %%
showFolderTree('E:\Project_operation\Bharat\KG\\')
# Out:
# /
# 3) DSF#1 DGH/
#   1) GSKV & GS-59- Information Dockets/
#     GS-59-1A/
#       Figure/
#         Fig-10_files/
#         Fig-12_files/
#         Fig-14_files/
#         Fig-15_files/
#         Fig-16_files/
#         Fig-1_files/
#         Fig-25_files/
#         Fig-2_files/
#         Fig-3_files/
#         Fig-4_files/
#         Fig-6_files/
#         Fig-8_files/
#       PART_A_files/
#       Table/
#         TABLE 2_files/
#         Table 3_files/
#         Table-4_files/
#         Table-5_files/
#         Table-6_files/
#         Table-7_files/
#     GS-KV-1/
#       Figure/
#         Fig-10_files/
#         Fig-11_files/
#         Fig-12_files/
#         Fig-13_files/
#         Fig-14_files/
#         Fig-15_files/
#         Fig-16_files/
#         Fig-1_files/
#         Fig-2a_files/
#         Fig-2_files/
#         Fig-3_files/
#         Fig-4_files/
#         Fig-6_files/
#         Fig-7_files/
#         Fig-8_files/
#         Fig-9_files/
#       First Page-_files/
#       PART_A_files/
#       Table/
#         Table-11_files/
#     Start_files/
#   2) GS-KV-1 and GS-59   Block Data/
#     data from dgh dec 2017/
#       LOG data/
#     FDP_Report_GSKV_ KRPEL_Final/
#     GS-KV-1 and GS-59 Data/
#       GSKV1-Annexure-III/
#         GSKV1_GS591A_Seismic_Data/
#         GSKV1_MAPS/
#         Well_GS-59-1/
#         Well_GS-KV-1/
#     GS-KV-1Cluster DSF-2016/
#       Data Package _Part B/
#         Content/
#         Reports_GS-59/
#           Additional Data/
#           FERs/
#           Oil and Gas Composition Analysis Report/
#           VSP - Check shot Survey Report/
#           WCRs/
#             WCR GS-59-1A/
#               ANNEURES/
#               Figures/
#         Reports_GS-KV/
#           Additional Data/
#           FERs/
#           Reservoir Study Report/
#           WCRs/
#       Data Package_PartA/
#         Seismic/
#           2D/
#           3D/
#         Well Data/
#           DLIS/
#             GS 59 ssreddy in pdf/
#           LOG MOTIF/
#   3) Processed data of GSKV Block STACK MERGE_3D_FINAL_MIGRATION/
#   4) Raw data of GSKV KG-PG_OFFSHORE_IF-B_1B-C/
# 4) 11-15 MF with ONGC/
#   11) Mulkipalli/
#     1) Mulikipalli Information docket/
#     2) Mulikipalli field boundary/
#     3) Mulikipalli WCR/
#     4) Mulikipalli well logs/
#       dataview_software/
#       LASVIEWER/
#       MUL1/
#       MUL2/
#       MULIKIPALLI #1/
#         LAS/
#         pdf/
#         TIFF/
#       MULIKIPALLI #2/
#         LAS/
#         TIFF/
#       mulikipalli logs/
#       Mullikipalle_DLIS/
#     6) Mulikipalli-FER/
#     7) Mulikipali Seismic data/
#       2D Seismic - CHP, MDP, MLP, SKP & MGP/
#         chintalapalli SEGY/
#           chintalapalli SEGY/
#         chintalapalli segy partII/
#           AP-110 chintalapalli/
#           AP-128 chintalapalli/
#         CHINTANAPALLI/
#         isl lines  chintalapalli/
#         magatapalli SEGY/
#         magatapally_segy part II/
#         mulikapalli SEGY/
#         srikattapalli SEGY-1/
#         srikattapalli SEGY-1.1/
#         srikattapalli SEGY_19.12.07/
#         srikattapalli SEGY_20.12.2007/
#       2D SEISMIC DATA FROM KG_ 01.01.2008/
#       2D Seismic KG - MLP/
#         mulikapalli SEGY/
#       3D Seismic, MGP, MLP & CHP _ 01.01.2008/
#       Mulkipalli SEGY/
#       Seismic/
#   12) Magatapalli/
#     1) Magatapalli Information Docket/
#     2) Magatapalli field boundary/
#     3) Magatapalli - WCR/
#     4) Magatapalli well Logs/
#       lasviewoffline/
#       MAGATAPALLI #1/
#         LAS/
#         SPLICE/
#         TIFF/
#       MAGATAPALLI #2/
#         LAS/
#         SPLICE/
#         TIFF/
#       MAGATAPALLI #3/
#         LAS/
#         TIFF/
#       MAGATAPALLI #4/
#         LAS/
#         SPLICE/
#         TIFF/
#       Magatapalli-las/
#         mag1/
#         mag2/
#         mag3/
#         mag4/
#       Magatapalli_DLIS/
#       VSP Data MGP/
#     5) Magatapalli - Resrvoir data -2&3/
#     6) Magatapalli- FER/
#     7) Magatapalli seismic data/
#       2D Seismic - CHP, MDP, MLP, SKP & MGP/
#         chintalapalli SEGY/
#           chintalapalli SEGY/
#         chintalapalli segy partII/
#           AP-110 chintalapalli/
#           AP-128 chintalapalli/
#         CHINTANAPALLI/
#         isl lines  chintalapalli/
#         magatapalli SEGY/
#         magatapally_segy part II/
#         mulikapalli SEGY/
#         srikattapalli SEGY-1/
#         srikattapalli SEGY-1.1/
#         srikattapalli SEGY_19.12.07/
#         srikattapalli SEGY_20.12.2007/
#       3D Seismic, MGP, MLP & CHP _ 01.01.2008/
#       magatapalli SEGY/
#       magatapally_segy part II/
#       VSP Data MGP/
#     9) Magatapalli additional data/
#       Magatapalli 1-2/
#         2D Seismic/
#         Logs/
#           lasviewoffline/
#           Magatapalli-las/
#             mag1/
#             mag2/
#             mag3/
#             mag4/
#           Magatapalli_DLIS/
#       Magatapalli 2-2/
#         Datapackage/
#   13) Sirikattapalli/
#     1) Sirikattapalli -Information Docket/
#     2) Sirikattapalli field boundary/
#     3) Sirikattapalli WCR/
#     4) Sirikattapalli well logs/
#       Comp.Log_Sirikattapalli-1/
#       Logs_Lass,Sirikattapall-1/
#         dataview_software/
#       SIRIKATTAPALLI #1/
#         LAS/
#         SPLICE/
#         tif & pdf/
#       Sirikattapalli_DLIS/
#     5) Sirikattapalli reservoir study/
#     6) Sirikattapalli - FER/
#     7) Sirikattapalli seismic data/
#       2D Seismic/
#         Srikattapalli/
#       2D Seismic - CHP, MDP, MLP, SKP & MGP/
#         chintalapalli SEGY/
#           chintalapalli SEGY/
#         chintalapalli segy partII/
#           AP-110 chintalapalli/
#           AP-128 chintalapalli/
#         CHINTANAPALLI/
#         isl lines  chintalapalli/
#         magatapalli SEGY/
#         magatapally_segy part II/
#         mulikapalli SEGY/
#         srikattapalli SEGY-1/
#         srikattapalli SEGY-1.1/
#         srikattapalli SEGY_19.12.07/
#         srikattapalli SEGY_20.12.2007/
#       2d SEISMIC SKP/
#         srikattapalli SEGY-1/
#         srikattapalli SEGY-1.1/
#         srikattapalli SEGY_19.12.07/
#         srikattapalli SEGY_20.12.2007/
#       2D_velocity_SRIKATAPALLI/
#       3D seismic data_From ONGC-14 SEP 2010/
#       3D Seismic, MGP, MLP & CHP _ 01.01.2008/
#   14) Chintanapalli/
#     1) Chintalapalli Information docket/
#     2) Chintalapalli field boundary/
#     3) Chintalapalli WCR/
#     4) Chintalapalli well logs/
#       CHINTALAPALLI #1/
#         LAS/
#         SPLICE/
#         TIFF/
#       CHINTALAPALLI #6/
#         LAS/
#         SPLICE/
#         TIFF/
#       CHINTALAPALLI #8/
#         LAS/
#         SPLICE/
#         TIFF/
#       Log/
#         Chintalapalli_DLIS/
#     5) Chintanapalli- Reservoir study/
#       Reservoir report/
#     6) Chintalapalli -FER/
#       FER/
#     7) Chintalapalli Seismic data/
#       2D Seismic/
#         Chintalapalli/
#       2D Seismic - CHP, MDP, MLP, SKP & MGP/
#         chintalapalli SEGY/
#           chintalapalli SEGY/
#         chintalapalli segy partII/
#           AP-110 chintalapalli/
#           AP-128 chintalapalli/
#         CHINTANAPALLI/
#         isl lines  chintalapalli/
#         magatapalli SEGY/
#         magatapally_segy part II/
#         mulikapalli SEGY/
#         srikattapalli SEGY-1/
#         srikattapalli SEGY-1.1/
#         srikattapalli SEGY_19.12.07/
#         srikattapalli SEGY_20.12.2007/
#       2D Seismic- CHP/
#         chintalapalli SEGY/
#           chintalapalli SEGY/
#         chintalapalli segy partII/
#           AP-110 chintalapalli/
#           AP-128 chintalapalli/
#           chintalapalli segy partII-19.12.07/
#             AP-110 chintalapalli/
#             chintalapalli segy partII-19.12.07/
#               AP-110 chintalapalli/
#         isl lines  chintalapalli/
#       2D_velocity_CHINTALAPALLI/
#       3D Seismic, MGP, MLP & CHP _ 01.01.2008/
#       3D Sseismic, CHP - 01.01.2008/
#       chintalapalli SEGY/
#         chintalapalli SEGY/
#       chintalapalli segy partII/
#         AP-110 chintalapalli/
#         AP-128 chintalapalli/
#         chintalapalli segy partII-19.12.07/
#           AP-110 chintalapalli/
#           chintalapalli segy partII-19.12.07/
#             AP-110 chintalapalli/
#             chintalapalli segy partII-19.12.07/
#       isl lines  chintalapalli/
#     8) Chintalapalli REC maps/
#   15) Medapadu/
#     1) Medapadu Information Docket/
#     2) Medapadu field boundary/
#     3) Medapadu WCR/
#     4) Medapadu well logs/
#       MEDAPADU #1/
#         LAS/
#         SPLICE/
#         TIFF/
#       Medapadu_DLIS/
#     5) Medapadu Reservoir report/
#     6) Medapadu FER/
#     7) Medapadu Seismic data/
#       2D Seismic/
#         Medapadu/
#       2D Seismic - CHP, MDP, MLP, SKP & MGP/
#         chintalapalli SEGY/
#           chintalapalli SEGY/
#         chintalapalli segy partII/
#           AP-110 chintalapalli/
#           AP-128 chintalapalli/
#           chintalapalli segy partII-19.12.07/
#             AP-110 chintalapalli/
#             chintalapalli segy partII-19.12.07/
#         CHINTANAPALLI/
#         isl lines  chintalapalli/
#         magatapalli SEGY/
#         magatapally_segy part II/
#         mulikapalli SEGY/
#         srikattapalli SEGY-1/
#         srikattapalli SEGY-1.1/
#         srikattapalli SEGY_19.12.07/
#         srikattapalli SEGY_20.12.2007/
#       2D Seismic-  MDP/
#       2D_velocity_Medapadu/
#       3D seismic data/
#       3D Seismic, MGP, MLP & CHP _ 01.01.2008/
#     8) Medapadu REC maps/
# 5) 16 DSF#3 with DGH/
#   1) Sanarudravaram/
#     1) Sanarudravaram Well completion report/
#     2) Sanarudravaram Well Logs/
#     3) Sanarudravaram Seismic data Sanarudravaram/
#       2D Sanaruravaram/
#       3D Sanaruravaram/
#       Seismic Reports Sanaruravaram/
#         2D/
#           GEOLOGICAL_REPORT/
#           NAVIGATION/
